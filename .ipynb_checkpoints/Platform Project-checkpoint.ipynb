# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# file paths and merge
df = pd.read_csv('NetflixData/NetflixData.csv')
df_1=pd.read_csv('HBOData/HBOData.csv')
df_2=pd.read_csv('AmazonPrimeData/APData.csv')

merged_df=pd.concat([df, df_1, df_2], ignore_index=True)


merged_df.head()
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm82169                                Rocky  MOVIE
# 2   tm17823                               Grease  MOVIE
# 3  tm191099                            The Sting  MOVIE
# 4   tm69975                             Rocky II  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  When world heavyweight boxing champion, Apollo...          1976
# 2  Australian good girl Sandy and greaser Danny f...          1978
# 3  A novice con man teams up with an acknowledged...          1973
# 4  After Rocky goes the distance with champ Apoll...          1979
#
#   age_certification  runtime                                 genres  \
# 0             TV-MA       51                      ['documentation']
# 1                PG      119                     ['drama', 'sport']
# 2                PG      110                  ['romance', 'comedy']
# 3                PG      129  ['crime', 'drama', 'comedy', 'music']
# 4                PG      119                     ['drama', 'sport']
#
#   production_countries  seasons    imdb_id  imdb_score  imdb_votes  \
# 0               ['US']      1.0        NaN         NaN         NaN
# 1               ['US']      NaN  tt0075148         8.1    588100.0
# 2               ['US']      NaN  tt0077631         7.2    283316.0
# 3               ['US']      NaN  tt0070735         8.3    266738.0
# 4               ['US']      NaN  tt0079817         7.3    216307.0
#
#    tmdb_popularity  tmdb_score Platform
# 0            0.601         NaN  Netflix
# 1          106.361       7.782  Netflix
# 2           33.160       7.406  Netflix
# 3           24.616       8.020  Netflix
# 4           75.699       7.246  Netflix

# %%
new_column_names = {'Age Certification': 'Rating',
                   }
merged_df.columns = merged_df.columns.str.title().str.replace('_', ' ')

merged_df.rename(columns=new_column_names, inplace=True)

merged_df.head()
# Out:
#          Id                                Title   Type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm82169                                Rocky  MOVIE
# 2   tm17823                               Grease  MOVIE
# 3  tm191099                            The Sting  MOVIE
# 4   tm69975                             Rocky II  MOVIE
#
#                                          Description  Release Year Rating  \
# 0  This collection includes 12 World War II-era p...          1945  TV-MA
# 1  When world heavyweight boxing champion, Apollo...          1976     PG
# 2  Australian good girl Sandy and greaser Danny f...          1978     PG
# 3  A novice con man teams up with an acknowledged...          1973     PG
# 4  After Rocky goes the distance with champ Apoll...          1979     PG
#
#    Runtime                                 Genres Production Countries  \
# 0       51                      ['documentation']               ['US']
# 1      119                     ['drama', 'sport']               ['US']
# 2      110                  ['romance', 'comedy']               ['US']
# 3      129  ['crime', 'drama', 'comedy', 'music']               ['US']
# 4      119                     ['drama', 'sport']               ['US']
#
#    Seasons    Imdb Id  Imdb Score  Imdb Votes  Tmdb Popularity  Tmdb Score  \
# 0      1.0        NaN         NaN         NaN            0.601         NaN
# 1      NaN  tt0075148         8.1    588100.0          106.361       7.782
# 2      NaN  tt0077631         7.2    283316.0           33.160       7.406
# 3      NaN  tt0070735         8.3    266738.0           24.616       8.020
# 4      NaN  tt0079817         7.3    216307.0           75.699       7.246
#
#   Platform
# 0  Netflix
# 1  Netflix
# 2  Netflix
# 3  Netflix
# 4  Netflix

# %%
columns_deleted = ['Id', 'Imdb Votes', 'Imdb Id', 'Tmdb Popularity']

merged_df.drop(columns = columns_deleted, inplace= True)

merged_df.head()
# Out:
#                                  Title   Type  \
# 0  Five Came Back: The Reference Films   SHOW
# 1                                Rocky  MOVIE
# 2                               Grease  MOVIE
# 3                            The Sting  MOVIE
# 4                             Rocky II  MOVIE
#
#                                          Description  Release Year Rating  \
# 0  This collection includes 12 World War II-era p...          1945  TV-MA
# 1  When world heavyweight boxing champion, Apollo...          1976     PG
# 2  Australian good girl Sandy and greaser Danny f...          1978     PG
# 3  A novice con man teams up with an acknowledged...          1973     PG
# 4  After Rocky goes the distance with champ Apoll...          1979     PG
#
#    Runtime                                 Genres Production Countries  \
# 0       51                      ['documentation']               ['US']
# 1      119                     ['drama', 'sport']               ['US']
# 2      110                  ['romance', 'comedy']               ['US']
# 3      129  ['crime', 'drama', 'comedy', 'music']               ['US']
# 4      119                     ['drama', 'sport']               ['US']
#
#    Seasons  Imdb Score  Tmdb Score Platform
# 0      1.0         NaN         NaN  Netflix
# 1      NaN         8.1       7.782  Netflix
# 2      NaN         7.2       7.406  Netflix
# 3      NaN         8.3       8.020  Netflix
# 4      NaN         7.3       7.246  Netflix

# %% [markdown]
# Top 20 Shows/Movies on Each Streaming Platform

# %%
#sorting to platform = Netflix
netflix_data_df = merged_df[merged_df['Platform']=='Netflix']
netflix_shows_df = netflix_data_df[netflix_data_df['Type']=='SHOW']
netflix_movies_df = netflix_data_df[netflix_data_df['Type']=='MOVIE']

# %%
#Netflix top 20 shows
netflix_top_shows_df = netflix_shows_df.sort_values(by='Imdb Score', ascending = False)

netflix_top_20_shows_df = netflix_top_shows_df.head(20)

custom_index= range(1,21)

netflix_top_20_shows_df.set_index(pd.Index(custom_index), inplace=True)
netflix_top_20_shows_df
# Out:
#                               Title  Type  \
# 1                          #ABtalks  SHOW
# 2                   Crazy Delicious  SHOW
# 3                      Breaking Bad  SHOW
# 4                          Khawatir  SHOW
# 5                        The Chosen  SHOW
# 6        Avatar: The Last Airbender  SHOW
# 7                        Our Planet  SHOW
# 8                        Reply 1988  SHOW
# 9                    The Last Dance  SHOW
# 10      Story Time Book: Read-Along  SHOW
# 11                        My Mister  SHOW
# 12                     Kota Factory  SHOW
# 13                           Arcane  SHOW
# 14                           Okupas  SHOW
# 15                       DEATH NOTE  SHOW
# 16                  Hunter x Hunter  SHOW
# 17                  Attack on Titan  SHOW
# 18                       Still Game  SHOW
# 19                 When They See Us  SHOW
# 20  Raja, Rasoi Aur Anya Kahaniyaan  SHOW
#
#                                           Description  Release Year Rating  \
# 1   #ABtalks is a YouTube interview show hosted by...          2018  TV-PG
# 2   Everyday meals are turned into extraordinary c...          2017    NaN
# 3   When Walter White, a New Mexico chemistry teac...          2008  TV-MA
# 4   A TV show devoted to help young people to be m...          2005  TV-14
# 5   The life of Christ through the eyes of those w...          2019  TV-PG
# 6   In a war-torn world of elemental magic, a youn...          2005  TV-Y7
# 7   Experience our planet's natural beauty and exa...          2019   TV-G
# 8   A nostalgic trip back to the late 1980s throug...          2015  TV-14
# 9   A 10-part documentary chronicling the untold s...          2020  TV-MA
# 10  Kids can read along with illustrated books tha...          2022   TV-Y
# 11  In a world that is less than kind, a young wom...          2018  TV-14
# 12  In a city of coaching centers known to train I...          2019  TV-MA
# 13  Amid the stark discord of twin cities Piltover...          2021  TV-14
# 14  During the year 2000, Ricardo, Pollo, Walter a...          2000  TV-MA
# 15  Light Yagami is an ace student with great pros...          2006  TV-14
# 16  Twelve-year-old Gon Freecss one day discovers ...          2011  TV-14
# 17  After his hometown is destroyed and his mother...          2013  TV-MA
# 18  Cult Scottish comedy about the lives of two OA...          2002  TV-MA
# 19  Five teens from Harlem become trapped in a nig...          2019  TV-MA
# 20  Explore the history and flavors of regional In...          2014    NaN
#
#     Runtime                                             Genres  \
# 1        78                                                 []
# 2        47                                        ['reality']
# 3        48           ['drama', 'comedy', 'crime', 'thriller']
# 4        19                     ['reality', 'scifi', 'family']
# 5        49                               ['drama', 'history']
# 6        24       ['animation', 'action', 'family', 'fantasy']
# 7        50                                  ['documentation']
# 8        71           ['comedy', 'drama', 'family', 'romance']
# 9        50              ['documentation', 'history', 'sport']
# 10       31                                      ['animation']
# 11       70                                ['drama', 'family']
# 12       41                                ['comedy', 'drama']
# 13       41  ['scifi', 'action', 'drama', 'animation', 'fan...
# 14       40                                 ['drama', 'crime']
# 15       24  ['animation', 'drama', 'fantasy', 'thriller', ...
# 16       23  ['action', 'drama', 'animation', 'comedy', 'fa...
# 17       23  ['horror', 'animation', 'action', 'drama', 'fa...
# 18       29                             ['comedy', 'european']
# 19       74                      ['drama', 'crime', 'history']
# 20       29                       ['history', 'documentation']
#
#    Production Countries  Seasons  Imdb Score  Tmdb Score Platform
# 1                    []      1.0         9.6         NaN  Netflix
# 2                ['GB']      1.0         9.6       7.500  Netflix
# 3                ['US']      5.0         9.5       8.868  Netflix
# 4                    []     11.0         9.5         NaN  Netflix
# 5                ['US']      3.0         9.3       8.583  Netflix
# 6                ['US']      3.0         9.3       8.700  Netflix
# 7                ['GB']      1.0         9.3       8.538  Netflix
# 8                ['KR']      1.0         9.2       8.652  Netflix
# 9                ['US']      1.0         9.1       8.202  Netflix
# 10                   []      1.0         9.1         NaN  Netflix
# 11               ['KR']      1.0         9.1       8.347  Netflix
# 12               ['IN']      2.0         9.0       8.100  Netflix
# 13               ['US']      1.0         9.0       8.744  Netflix
# 14               ['AR']      1.0         9.0       8.635  Netflix
# 15               ['JP']      1.0         9.0       8.642  Netflix
# 16               ['JP']      1.0         9.0       8.661  Netflix
# 17               ['JP']      4.0         9.0       8.600  Netflix
# 18               ['GB']      9.0         8.9       8.250  Netflix
# 19               ['US']      1.0         8.9       8.241  Netflix
# 20               ['IN']      4.0         8.9       6.000  Netflix

# %%
#Netflix top 20 movies
netflix_top_movies_df = netflix_movies_df.sort_values(by='Imdb Score', ascending = False)

netflix_top_20_movies_df = netflix_top_movies_df.head(20)

netflix_top_20_movies_df.set_index(pd.Index(custom_index), inplace= True)

netflix_top_20_movies_df
# Out:
#                                                 Title   Type  \
# 1                                     The Dark Knight  MOVIE
# 2       The Lord of the Rings: The Return of the King  MOVIE
# 3                                   Split at the Root  MOVIE
# 4            David Attenborough: A Life on Our Planet  MOVIE
# 5   The Lord of the Rings: The Fellowship of the Ring  MOVIE
# 6                                   C/o Kancharapalem  MOVIE
# 7                           Nanpakal Nerathu Mayakkam  MOVIE
# 8                                        Forrest Gump  MOVIE
# 9                          Chhota Bheem Neeli Pahaadi  MOVIE
# 10              The Lord of the Rings: The Two Towers  MOVIE
# 11                                 Bo Burnham: Inside  MOVIE
# 12                                A Lion in the House  MOVIE
# 13  Chhota Bheem & Krishna: Pataliputra- City of t...  MOVIE
# 14                                    A Second Chance  MOVIE
# 15                              Merku Thodarchi Malai  MOVIE
# 16                            In Our Mothers' Gardens  MOVIE
# 17                                      Rubaru Roshni  MOVIE
# 18                                         Anbe Sivam  MOVIE
# 19                                Black Sunshine Baby  MOVIE
# 20                            Springsteen On Broadway  MOVIE
#
#                                           Description  Release Year Rating  \
# 1   Batman raises the stakes in his war on crime. ...          2008  PG-13
# 2   Aragorn is revealed as the heir to the ancient...          2003  PG-13
# 3   When a Guatemalan mother seeking asylum was se...          2022    NaN
# 4   The story of life on our planet by the man who...          2020     PG
# 5   Young hobbit Frodo Baggins, after inheriting a...          2001  PG-13
# 6   From a schoolboy’s crush to a middle-aged bach...          2018     PG
# 7   A group of Malayali travellers were returning ...          2023    NaN
# 8   A man with a low IQ has accomplished great thi...          1994  PG-13
# 9   The kids are excited, as they have all planned...          2021      G
# 10  Frodo and Sam are trekking to Mordor to destro...          2002  PG-13
# 11  Stuck in COVID-19 lockdown, US comedian and mu...          2021      R
# 12  Five families struggle with the ups and downs ...          2006    NaN
# 13  Krishna needs Bheem's help: The ruined city of...          2009      G
# 14  Popoy and Basha have had a wonderful wedding, ...          2018    NaN
# 15  Living on the borders of Kerala and Tamil Nadu...          2018    NaN
# 16  In Our Mothers' Gardens celebrates the strengt...          2021    NaN
# 17  The movie traces three real-life incidents tha...          2019    NaN
# 18  Nalla Sivam and Anbarasu meet under different ...          2003    NaN
# 19  Family memories and personal art movingly port...          2023    NaN
# 20  Springsteen on Broadway is a solo acoustic per...          2018    NaN
#
#     Runtime                                         Genres  \
# 1       152       ['drama', 'thriller', 'action', 'crime']
# 2       201                 ['fantasy', 'action', 'drama']
# 3        96                              ['documentation']
# 4        83                              ['documentation']
# 5       178                 ['fantasy', 'action', 'drama']
# 6       152                                      ['drama']
# 7       107                            ['drama', 'comedy']
# 8       142                 ['comedy', 'drama', 'romance']
# 9        63                                  ['animation']
# 10      179                 ['action', 'fantasy', 'drama']
# 11       88        ['comedy', 'drama', 'music', 'reality']
# 12      225                              ['documentation']
# 13       65                                  ['animation']
# 14      130  ['drama', 'family', 'sport', 'documentation']
# 15      122                                      ['drama']
# 16       84                              ['documentation']
# 17      110                              ['documentation']
# 18      160                            ['comedy', 'drama']
# 19       85                              ['documentation']
# 20      153                     ['documentation', 'music']
#
#    Production Countries  Seasons  Imdb Score  Tmdb Score Platform
# 1          ['GB', 'US']      NaN         9.0       8.508  Netflix
# 2          ['NZ', 'US']      NaN         9.0       8.474  Netflix
# 3                ['US']      NaN         8.9         NaN  Netflix
# 4                ['GB']      NaN         8.9       8.500  Netflix
# 5          ['NZ', 'US']      NaN         8.8       8.394  Netflix
# 6                ['IN']      NaN         8.8       7.500  Netflix
# 7                ['IN']      NaN         8.8       7.200  Netflix
# 8                ['US']      NaN         8.8       8.479  Netflix
# 9                    []      NaN         8.8      10.000  Netflix
# 10         ['NZ', 'US']      NaN         8.8       8.375  Netflix
# 11               ['US']      NaN         8.7       8.186  Netflix
# 12               ['US']      NaN         8.7       6.500  Netflix
# 13               ['IN']      NaN         8.6      10.000  Netflix
# 14               ['PH']      NaN         8.6       7.100  Netflix
# 15               ['IN']      NaN         8.6       7.400  Netflix
# 16               ['US']      NaN         8.6         NaN  Netflix
# 17               ['IN']      NaN         8.6       7.700  Netflix
# 18               ['IN']      NaN         8.6       7.427  Netflix
# 19               ['IN']      NaN         8.5       2.000  Netflix
# 20               ['US']      NaN         8.5       8.000  Netflix

# %%
#sorting to platform = Amazon Prime
amazon_data_df = merged_df[merged_df['Platform']=='Amazon Prime']
amazon_shows_df = amazon_data_df[amazon_data_df['Type']=='SHOW']
amazon_movies_df = amazon_data_df[amazon_data_df['Type']=='MOVIE']

# %%
#Amazon Prime top 20 shows
amazon_top_shows_df = amazon_shows_df.sort_values(by='Imdb Score', ascending = False)

amazon_top_20_shows_df = amazon_top_shows_df.head(20)

custom_index= range(1,21)

amazon_top_20_shows_df.set_index(pd.Index(custom_index), inplace=True)
amazon_top_20_shows_df
# Out:
#                           Title  Type  \
# 1     Water Helps the Blood Run  SHOW
# 2                    Life After  SHOW
# 3               Jinny's Kitchen  SHOW
# 4                         Denis  SHOW
# 5                    The Chosen  SHOW
# 6         Subaru Launch Control  SHOW
# 7                    Reply 1988  SHOW
# 8                    Intentions  SHOW
# 9      Daisy & the Gumboot Kids  SHOW
# 10          Rules of Engagement  SHOW
# 11    Harmony with A. R. Rahman  SHOW
# 12               Free to Choose  SHOW
# 13  Mr. Monkey, Monkey Mechanic  SHOW
# 14  I Fell In Love With A Sanki  SHOW
# 15                   DEATH NOTE  SHOW
# 16               Brain Candy TV  SHOW
# 17             Corazón Contento  SHOW
# 18              Clarkson's Farm  SHOW
# 19             L.A. Frock Stars  SHOW
# 20              Hunter x Hunter  SHOW
#
#                                           Description  Release Year Rating  \
# 1   Five orphan girls from diverse backgrounds, ca...          2019    NaN
# 2   So what happens to the players when their dail...          2022    NaN
# 3   A spin-off of the Youn's Kitchen series, sched...          2023    NaN
# 4   Denis, or DenisDaily, is a Canadian YouTuber w...          2016    NaN
# 5   The life of Christ through the eyes of those w...          2019  TV-PG
# 6   Go behind closed doors with Subaru Motorsports...          2013    NaN
# 7   A nostalgic trip back to the late 1980s throug...          2015  TV-14
# 8   Three former law students run an illegal opera...          2021    NaN
# 9   Daisy the mouse loves nature. In each episode ...          2021    NaN
# 10  Rules of Engagement is a comedy about the diff...          2007  TV-14
# 11  Harmony with A.R Rahman' is a curated explorat...          2018   TV-G
# 12  Free to Choose is a ten-part television series...          1980    NaN
# 13  Mr. Monkey, Monkey Mechanic is the go-to monke...          2017    NaN
# 14  Two introverts fall hopelessly in love with on...          2019    NaN
# 15  Light Yagami is an ace student with great pros...          2006  TV-14
# 16  Join Lizzy the Dog and a collection of action-...          2017   TV-Y
# 17  This series frames 3 Mexican families from dif...          2018    NaN
# 18  Follow Jeremy Clarkson as he embarks on his la...          2021  TV-PG
# 19  Series is a window into the world of high-end ...          2013  TV-PG
# 20  Twelve-year-old Gon Freecss one day discovers ...          2011  TV-14
#
#     Runtime                                             Genres  \
# 1        29                                ['comedy', 'drama']
# 2        23                                          ['sport']
# 3        97                                        ['reality']
# 4        15                                         ['comedy']
# 5        49                               ['drama', 'history']
# 6        21                                          ['sport']
# 7        71           ['comedy', 'drama', 'family', 'romance']
# 8        24                                ['comedy', 'drama']
# 9         6                                         ['family']
# 10       23         ['comedy', 'drama', 'romance', 'thriller']
# 11       43                         ['documentation', 'music']
# 12       57                                  ['documentation']
# 13        5                                      ['animation']
# 14       16           ['family', 'romance', 'comedy', 'drama']
# 15       24  ['animation', 'drama', 'fantasy', 'thriller', ...
# 16        6                            ['animation', 'family']
# 17       27                                ['comedy', 'drama']
# 18       46             ['reality', 'documentation', 'comedy']
# 19       32                                        ['reality']
# 20       23  ['action', 'drama', 'animation', 'comedy', 'fa...
#
#    Production Countries  Seasons  Imdb Score  Tmdb Score      Platform
# 1                ['US']      1.0         9.7         NaN  Amazon Prime
# 2                    []      1.0         9.5         NaN  Amazon Prime
# 3                ['KR']      1.0         9.4       6.000  Amazon Prime
# 4          ['US', 'FR']      4.0         9.4         NaN  Amazon Prime
# 5                ['US']      3.0         9.3       8.583  Amazon Prime
# 6                ['US']      4.0         9.3         NaN  Amazon Prime
# 7                ['KR']      1.0         9.2       8.652  Amazon Prime
# 8                ['US']      1.0         9.2         NaN  Amazon Prime
# 9                ['US']      4.0         9.2         NaN  Amazon Prime
# 10               ['US']      7.0         9.2       7.200  Amazon Prime
# 11               ['IN']      1.0         9.1         NaN  Amazon Prime
# 12               ['US']      2.0         9.1       7.800  Amazon Prime
# 13               ['US']      2.0         9.1         NaN  Amazon Prime
# 14               ['IN']      1.0         9.1         NaN  Amazon Prime
# 15               ['JP']      1.0         9.0       8.642  Amazon Prime
# 16                   []      3.0         9.0         NaN  Amazon Prime
# 17               ['MX']      1.0         9.0      10.000  Amazon Prime
# 18               ['GB']      2.0         9.0       8.250  Amazon Prime
# 19               ['ZA']      2.0         9.0         NaN  Amazon Prime
# 20               ['JP']      1.0         9.0       8.661  Amazon Prime

# %%
#Amazon Prime top 20 movies
amazon_top_movies_df = amazon_movies_df.sort_values(by='Imdb Score', ascending = False)

amazon_top_20_movies_df = amazon_top_movies_df.head(20)

amazon_top_20_movies_df.set_index(pd.Index(custom_index), inplace= True)

amazon_top_20_movies_df
# Out:
#                                                 Title   Type  \
# 1                                          Pawankhind  MOVIE
# 2                                      Romeo & Juliet  MOVIE
# 3                              COD (Cash On Delivery)  MOVIE
# 4   The 1975 'At Their Very Best' Live from Madiso...  MOVIE
# 5                                         Last Resort  MOVIE
# 6        Chhote Ustaad-Precaution Is Better Than Cure  MOVIE
# 7                                     Suffer for Good  MOVIE
# 8   Yakov Smirnoff's Happily Ever Laughter : The N...  MOVIE
# 9                                            Jai Bhim  MOVIE
# 10                                 Because We're Done  MOVIE
# 11            Steven Banks: Home Entertainment Center  MOVIE
# 12                                          Last Days  MOVIE
# 13                 Alexander Babu: Alex in Wonderland  MOVIE
# 14                                  Pazhagiya Naatkal  MOVIE
# 15                                    Nuvvante Pichhe  MOVIE
# 16        Unity: The Latin Tribute to Michael Jackson  MOVIE
# 17                                       Toxification  MOVIE
# 18                                       12 Angry Men  MOVIE
# 19                               The Friendliest Town  MOVIE
# 20                                       Siddhi Seere  MOVIE
#
#                                           Description  Release Year Rating  \
# 1   The story of the Maratha Warriors at the battl...          2022    NaN
# 2   In Verona, bad blood between the Montague and ...          2013  PG-13
# 3   COD is a story about a jobless artist who hija...          2021    NaN
# 4   In support of their fifth studio album 'Being ...          2022    NaN
# 5   Two terminally ill hospice residents conspire ...          2022      R
# 6   Chhote Ustad-precaution is better than cure, s...          2021    NaN
# 7   By teaching the sport he loves an aging boxing...          2020    NaN
# 8   Fans who loved the comedy of Russian born ente...          2016     PG
# 9   A pregnant woman from a primitive tribal commu...          2021    NaN
# 10  A married man going thru a mid life crisis bel...          2022    NaN
# 11  In this brilliant one-man show, the mild-manne...          1989    NaN
# 12  A widow struggling to make ends meet is diagno...          2019    NaN
# 13  This is Alex’s first solo standup special. Thi...          2019    NaN
# 14                                                NaN          2021    NaN
# 15  A Bank Employ named Ajay who is good at person...          2021    NaN
# 16  This unique musical tribute to the King of Pop...          2015    NaN
# 17  Toxification of land, body and mind examines t...          2020    NaN
# 18  The defense and the prosecution have rested an...          1957    NaN
# 19  The first black police chief of a small racial...          2019  PG-13
# 20  An old widow decides to steal a rich saree to ...          2019    NaN
#
#     Runtime                            Genres Production Countries  Seasons  \
# 1       153    ['history', 'action', 'drama']               ['IN']      NaN
# 2       118  ['drama', 'romance', 'european']               ['GB']      NaN
# 3       130                         ['drama']                   []      NaN
# 4       124        ['documentation', 'music']               ['US']      NaN
# 5        92                         ['drama']               ['CA']      NaN
# 6       300                         ['crime']                   []      NaN
# 7        70                 ['documentation']               ['US']      NaN
# 8        60                        ['comedy']               ['US']      NaN
# 9       164    ['drama', 'thriller', 'crime']               ['IN']      NaN
# 10      108                        ['comedy']                   []      NaN
# 11       60                        ['comedy']               ['US']      NaN
# 12      146                         ['drama']                   []      NaN
# 13      136                        ['comedy']               ['IN']      NaN
# 14      127                         ['drama']               ['IN']      NaN
# 15      102                       ['romance']                   []      NaN
# 16       54                         ['music']               ['US']      NaN
# 17       66                 ['documentation']               ['IN']      NaN
# 18       97                ['drama', 'crime']               ['US']      NaN
# 19       77                 ['documentation']               ['US']      NaN
# 20      135                         ['drama']               ['IN']      NaN
#
#     Imdb Score  Tmdb Score      Platform
# 1          9.9       5.200  Amazon Prime
# 2          9.8       6.800  Amazon Prime
# 3          9.8         NaN  Amazon Prime
# 4          9.7       2.000  Amazon Prime
# 5          9.7         NaN  Amazon Prime
# 6          9.6         NaN  Amazon Prime
# 7          9.6         NaN  Amazon Prime
# 8          9.3         NaN  Amazon Prime
# 9          9.3       7.500  Amazon Prime
# 10         9.3         NaN  Amazon Prime
# 11         9.2       7.100  Amazon Prime
# 12         9.2         NaN  Amazon Prime
# 13         9.2       9.700  Amazon Prime
# 14         9.2         NaN  Amazon Prime
# 15         9.1         NaN  Amazon Prime
# 16         9.1         NaN  Amazon Prime
# 17         9.1         NaN  Amazon Prime
# 18         9.0       8.539  Amazon Prime
# 19         9.0         NaN  Amazon Prime
# 20         8.9         NaN  Amazon Prime

# %%
#sorting to platform = HBO
hbo_data_df = merged_df[merged_df['Platform']=='HBO']
hbo_shows_df = hbo_data_df[hbo_data_df['Type']=='SHOW']
hbo_movies_df = hbo_data_df[hbo_data_df['Type']=='MOVIE']

# %%
#HBO top 20 shows
hbo_top_shows_df = hbo_shows_df.sort_values(by='Imdb Score', ascending = False)

hbo_top_20_shows_df = hbo_top_shows_df.head(20)

custom_index= range(1,21)

hbo_top_20_shows_df.set_index(pd.Index(custom_index), inplace=True)
hbo_top_20_shows_df
# Out:
#                                   Title  Type  \
# 1                             Chernobyl  SHOW
# 2                      Band of Brothers  SHOW
# 3                              The Wire  SHOW
# 4                          The Sopranos  SHOW
# 5                     Eyes on the Prize  SHOW
# 6                       Game of Thrones  SHOW
# 7                        The Last of Us  SHOW
# 8                             Homegrown  SHOW
# 9                        Rick and Morty  SHOW
# 10          Batman: The Animated Series  SHOW
# 11             For The Love of Kitchens  SHOW
# 12                       Nathan For You  SHOW
# 13                         Kindergarten  SHOW
# 14                        The West Wing  SHOW
# 15                              Friends  SHOW
# 16              Joe Pera Talks With You  SHOW
# 17                 The World Between Us  SHOW
# 18                       True Detective  SHOW
# 19   Last Week Tonight with John Oliver  SHOW
# 20  Making Modern with Brooke and Brice  SHOW
#
#                                           Description  Release Year    Rating  \
# 1   The true story of one of the worst man-made ca...          2019     TV-MA
# 2   Drawn from interviews with survivors of Easy C...          2001     TV-MA
# 3   Told from the points of view of both the Balti...          2002     TV-MA
# 4   The story of New Jersey-based Italian-American...          1999     TV-MA
# 5   The definitive story of the Civil Rights era f...          1987     TV-PG
# 6   Seven noble families fight for control of the ...          2011     TV-MA
# 7   Twenty years after modern civilization has bee...          2023     TV-MA
# 8   Jamila Norman helps families turn their backya...          2021       NaN
# 9   Rick is a mentally-unbalanced but scientifical...          2013     TV-MA
# 10  The Dark Knight battles crime in Gotham City w...          1992  TV-Y7-FV
# 11  Paul O'Leary, Helen Parker and Robin McLellan ...          2021       NaN
# 12  Self-proclaimed business expert, writer, direc...          2013     TV-14
# 13  Series that gets inside the hearts and minds o...          2001       NaN
# 14  The West Wing is an American television serial...          1999     TV-14
# 15  Six young people from New York City, on their ...          1994     TV-14
# 16  A teacher in Michigan's Upper Peninsula explor...          2018     TV-14
# 17  A ten-part hour-long series that follows the a...          2019       NaN
# 18  An American anthology police detective series ...          2014     TV-MA
# 19  A half-hour satirical look at the week in news...          2014     TV-MA
# 20                                  Plot under wraps.          2021       NaN
#
#     Runtime                                             Genres  \
# 1        65                   ['drama', 'thriller', 'history']
# 2        59              ['drama', 'war', 'history', 'action']
# 3        59                     ['drama', 'crime', 'thriller']
# 4        55                                 ['drama', 'crime']
# 5        57                       ['documentation', 'history']
# 6        58  ['scifi', 'drama', 'action', 'romance', 'fanta...
# 7        60  ['drama', 'action', 'horror', 'scifi', 'thrill...
# 8        24                         ['documentation', 'drama']
# 9        22         ['animation', 'scifi', 'action', 'comedy']
# 10       22  ['family', 'scifi', 'animation', 'action', 'cr...
# 11       42                                        ['reality']
# 12       25                        ['documentation', 'comedy']
# 13       27          ['documentation', 'animation', 'reality']
# 14       45                                          ['drama']
# 15       25                     ['comedy', 'drama', 'romance']
# 16       12                                         ['comedy']
# 17       52                                 ['drama', 'crime']
# 18       60                     ['drama', 'crime', 'thriller']
# 19       31                   ['comedy', 'reality', 'history']
# 20       24                                  ['documentation']
#
#    Production Countries  Seasons  Imdb Score  Tmdb Score Platform
# 1                ['US']      1.0         9.4       8.600      HBO
# 2                ['US']      1.0         9.4       8.454      HBO
# 3                ['US']      5.0         9.3       8.501      HBO
# 4                ['US']      6.0         9.2       8.603      HBO
# 5                ['US']      2.0         9.2       8.500      HBO
# 6                ['US']      8.0         9.2       8.400      HBO
# 7                ['US']      1.0         9.1       8.798      HBO
# 8                ['US']      3.0         9.1         NaN      HBO
# 9                ['US']      6.0         9.1       8.729      HBO
# 10               ['US']      4.0         9.0       8.489      HBO
# 11               ['GB']      2.0         9.0         NaN      HBO
# 12               ['US']      4.0         8.9       8.100      HBO
# 13               ['US']      1.0         8.9       8.000      HBO
# 14               ['US']      7.0         8.9       8.292      HBO
# 15               ['US']     10.0         8.9       8.456      HBO
# 16               ['US']      3.0         8.9       8.400      HBO
# 17               ['TW']      1.0         8.9       9.022      HBO
# 18               ['US']      4.0         8.9       8.289      HBO
# 19               ['US']     10.0         8.9       7.924      HBO
# 20               ['US']      1.0         8.9         NaN      HBO

# %%
#HBO top 20 movies
hbo_top_movies_df = hbo_movies_df.sort_values(by='Imdb Score', ascending = False)

hbo_top_20_movies_df = hbo_top_movies_df.head(20)

hbo_top_20_movies_df.set_index(pd.Index(custom_index), inplace= True)

hbo_top_20_movies_df
# Out:
#                                                 Title   Type  \
# 1                            The Shawshank Redemption  MOVIE
# 2                                     Celebrity Habla  MOVIE
# 3                                   Emergency Contact  MOVIE
# 4                                     The Dark Knight  MOVIE
# 5                 Euphoria: Trouble Don't Last Always  MOVIE
# 6       The Lord of the Rings: The Return of the King  MOVIE
# 7         Juan Luis Guerra 4.40: Entre Mar y Palmeras  MOVIE
# 8               The Lord of the Rings: The Two Towers  MOVIE
# 9                                   Celebrity Habla 2  MOVIE
# 10         Euphoria: F*ck Anyone Who’s Not A Sea Blob  MOVIE
# 11  The Lord of the Rings: The Fellowship of the Ring  MOVIE
# 12                Dave Chappelle: Killin' Them Softly  MOVIE
# 13                                         GoodFellas  MOVIE
# 14                 George Carlin: Jammin' in New York  MOVIE
# 15                                         The Matrix  MOVIE
# 16                    One Flew Over the Cuckoo's Nest  MOVIE
# 17                         Beah: A Black Woman Speaks  MOVIE
# 18  The Music in Me: The Leopards Take Manhattan -...  MOVIE
# 19                         Terminator 2: Judgment Day  MOVIE
# 20                           The Silence of the Lambs  MOVIE
#
#                                           Description  Release Year Rating  \
# 1   Framed in the 1940s for the double murder of h...          1994      R
# 2   See what celebrated Latino actors, newsmakers ...          2009     PG
# 3   Can 30-something Roxanna Biltmore handle the m...          2015    NaN
# 4   Batman raises the stakes in his war on crime. ...          2008  PG-13
# 5   After changing her mind to run away with Jules...          2020      R
# 6   Aragorn is revealed as the heir to the ancient...          2003  PG-13
# 7   The renowned Dominican composer, musician, pro...          2021     PG
# 8   Frodo and Sam are trekking to Mordor to destro...          2002  PG-13
# 9   See what celebrated Latino actors, newsmakers ...          2010     PG
# 10  Over the Christmas holiday, Jules reflects on ...          2021      R
# 11  Young hobbit Frodo Baggins, after inheriting a...          2001  PG-13
# 12  Dave Chappelle returns for a stand-up to D.C. ...          2000    NaN
# 13  The true story of Henry Hill, a half-Irish, ha...          1990      R
# 14  When George Carlin is asked which HBO concert ...          1992    NaN
# 15  Set in the 22nd century, The Matrix tells the ...          1999      R
# 16  A petty criminal fakes insanity to serve his s...          1975      R
# 17  Beah: A Black Woman Speaks is a 2003 documenta...          2003    NaN
# 18  Prepare for a fun-filled, emotional journey wi...          2008    NaN
# 19  Nearly 10 years have passed since Sarah Connor...          1991      R
# 20  Clarice Starling is a top student at the FBI's...          1991      R
#
#     Runtime                                    Genres Production Countries  \
# 1       143                                 ['drama']               ['US']
# 2        53                         ['documentation']               ['US']
# 3        54                                ['comedy']               ['US']
# 4       152  ['drama', 'thriller', 'action', 'crime']         ['GB', 'US']
# 5        57                                 ['drama']               ['US']
# 6       201            ['fantasy', 'action', 'drama']         ['NZ', 'US']
# 7        70                                 ['music']               ['DO']
# 8       179            ['action', 'fantasy', 'drama']         ['NZ', 'US']
# 9        58                         ['documentation']               ['US']
# 10       55                                 ['drama']               ['US']
# 11      178            ['fantasy', 'action', 'drama']         ['NZ', 'US']
# 12       58               ['comedy', 'documentation']               ['US']
# 13      145                        ['crime', 'drama']               ['US']
# 14       59               ['comedy', 'documentation']               ['US']
# 15      136                       ['action', 'scifi']               ['US']
# 16      133                                 ['drama']               ['US']
# 17       88                         ['documentation']               ['US']
# 18       30                         ['documentation']               ['US']
# 19      137           ['scifi', 'action', 'thriller']         ['FR', 'US']
# 20      118  ['drama', 'thriller', 'horror', 'crime']               ['US']
#
#     Seasons  Imdb Score  Tmdb Score Platform
# 1       NaN         9.3       8.702      HBO
# 2       NaN         9.3         NaN      HBO
# 3       NaN         9.2         NaN      HBO
# 4       NaN         9.0       8.508      HBO
# 5       NaN         9.0      10.000      HBO
# 6       NaN         9.0       8.474      HBO
# 7       NaN         8.9       8.300      HBO
# 8       NaN         8.8       8.375      HBO
# 9       NaN         8.8         NaN      HBO
# 10      NaN         8.8      10.000      HBO
# 11      NaN         8.8       8.394      HBO
# 12      NaN         8.7       8.067      HBO
# 13      NaN         8.7       8.465      HBO
# 14      NaN         8.7       7.982      HBO
# 15      NaN         8.7       8.200      HBO
# 16      NaN         8.7       8.423      HBO
# 17      NaN         8.7         NaN      HBO
# 18      NaN         8.7         NaN      HBO
# 19      NaN         8.6       8.100      HBO
# 20      NaN         8.6       8.344      HBO

# %%
#Printing output files of the top 20 as pictures (/output_files/top20/...)
#Netflix
netflix_top_path = "output_files/top20/Netflix/"
netflix_top_20_shows_df.to_csv(netflix_top_path + "netflix_top_20_shows.csv")
netflix_top_20_movies_df.to_csv(netflix_top_path + "netflix_top_20_movies.csv")

#Amazon Prime
amazon_top_path = "output_files/top20/Amazon Prime/"
amazon_top_20_shows_df.to_csv(amazon_top_path + "amazon_top_20_shows.csv")
amazon_top_20_movies_df.to_csv(amazon_top_path + "amazon_top_20_movies.csv")

#HBO
hbo_top_path = "output_files/top20/HBO/"
hbo_top_20_shows_df.to_csv(hbo_top_path + "hbo_top_20_shows.csv")
hbo_top_20_movies_df.to_csv(hbo_top_path + "hbo_top_20_movies.csv")

# %% [markdown]
# Titles by Time Period for Each Streaming Platform

# %%
#BINNNING - Netflix
Year_bins = [0,1963,1973,1983,1993,2003,2013, 2018, 2023]
bin_labels=['Before 1964','1964 to 1973','1974 to 1983', '1984 to 1993', '1994 to 2003','2004 to 2013','2014 to 2018', '2019 to 2023']

pd.cut(netflix_data_df['Release Year'], Year_bins, labels = bin_labels)
# Out:
# 0        Before 1964
# 1       1974 to 1983
# 2       1974 to 1983
# 3       1964 to 1973
# 4       1974 to 1983
#             ...
# 6132    2019 to 2023
# 6133    2019 to 2023
# 6134    2019 to 2023
# 6135    2019 to 2023
# 6136    2019 to 2023
# Name: Release Year, Length: 6137, dtype: category
# Categories (8, object): ['Before 1964' < '1964 to 1973' < '1974 to 1983' < '1984 to 1993' < '1994 to 2003' < '2004 to 2013' < '2014 to 2018' < '2019 to 2023']

# %%
netflix_data_df['Time Period']=pd.cut(netflix_data_df['Release Year'], Year_bins, labels = bin_labels)

netflix_data_df.head()
# Out:
# C:\Users\zmaso\AppData\Local\Temp\ipykernel_13372\928093264.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   netflix_data_df['Time Period']=pd.cut(netflix_data_df['Release Year'], Year_bins, labels = bin_labels)
#                                  Title   Type  \
# 0  Five Came Back: The Reference Films   SHOW
# 1                                Rocky  MOVIE
# 2                               Grease  MOVIE
# 3                            The Sting  MOVIE
# 4                             Rocky II  MOVIE
#
#                                          Description  Release Year Rating  \
# 0  This collection includes 12 World War II-era p...          1945  TV-MA
# 1  When world heavyweight boxing champion, Apollo...          1976     PG
# 2  Australian good girl Sandy and greaser Danny f...          1978     PG
# 3  A novice con man teams up with an acknowledged...          1973     PG
# 4  After Rocky goes the distance with champ Apoll...          1979     PG
#
#    Runtime                                 Genres Production Countries  \
# 0       51                      ['documentation']               ['US']
# 1      119                     ['drama', 'sport']               ['US']
# 2      110                  ['romance', 'comedy']               ['US']
# 3      129  ['crime', 'drama', 'comedy', 'music']               ['US']
# 4      119                     ['drama', 'sport']               ['US']
#
#    Seasons  Imdb Score  Tmdb Score Platform   Time Period
# 0      1.0         NaN         NaN  Netflix   Before 1964
# 1      NaN         8.1       7.782  Netflix  1974 to 1983
# 2      NaN         7.2       7.406  Netflix  1974 to 1983
# 3      NaN         8.3       8.020  Netflix  1964 to 1973
# 4      NaN         7.3       7.246  Netflix  1974 to 1983

# %%
time_period_counts_netflix = netflix_data_df['Time Period'].value_counts()
time_period_counts_netflix
# Out:
# Time Period
# 2019 to 2023    3497
# 2014 to 2018    1862
# 2004 to 2013     537
# 1994 to 2003     136
# 1984 to 1993      59
# 1974 to 1983      28
# 1964 to 1973      11
# Before 1964        7
# Name: count, dtype: int64

# %%
#Binning - Amazon
pd.cut(amazon_data_df['Release Year'], Year_bins, labels = bin_labels)
# Out:
# 9167      Before 1964
# 9168      Before 1964
# 9169      Before 1964
# 9170      Before 1964
# 9171      Before 1964
#              ...
# 20035    2019 to 2023
# 20036    2019 to 2023
# 20037    2019 to 2023
# 20038    2019 to 2023
# 20039    2019 to 2023
# Name: Release Year, Length: 10873, dtype: category
# Categories (8, object): ['Before 1964' < '1964 to 1973' < '1974 to 1983' < '1984 to 1993' < '1994 to 2003' < '2004 to 2013' < '2014 to 2018' < '2019 to 2023']

# %%
amazon_data_df['Time Period']=pd.cut(amazon_data_df['Release Year'], Year_bins, labels = bin_labels)
amazon_data_df.head()
# Out:
# C:\Users\zmaso\AppData\Local\Temp\ipykernel_13372\2560859749.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amazon_data_df['Time Period']=pd.cut(amazon_data_df['Release Year'], Year_bins, labels = bin_labels)
#                       Title   Type  \
# 9167  It's a Wonderful Life  MOVIE
# 9168              Duck Soup  MOVIE
# 9169        His Girl Friday  MOVIE
# 9170      The Three Stooges   SHOW
# 9171              Red River  MOVIE
#
#                                             Description  Release Year Rating  \
# 9167  A holiday favourite for generations...  George...          1946     PG
# 9168  Rufus T. Firefly is named president/dictator o...          1933    NaN
# 9169  Hildy, the journalist former wife of newspaper...          1940    NaN
# 9170  The Three Stooges were an American vaudeville ...          1934  TV-PG
# 9171  Headstrong Thomas Dunson starts a thriving Tex...          1948    NaN
#
#       Runtime                                             Genres  \
# 9167      130  ['drama', 'family', 'fantasy', 'romance', 'com...
# 9168       69                                  ['comedy', 'war']
# 9169       92                     ['drama', 'romance', 'comedy']
# 9170       19                               ['comedy', 'family']
# 9171      133          ['western', 'drama', 'romance', 'action']
#
#      Production Countries  Seasons  Imdb Score  Tmdb Score      Platform  \
# 9167               ['US']      NaN         8.6       8.261  Amazon Prime
# 9168               ['US']      NaN         7.8       7.357  Amazon Prime
# 9169               ['US']      NaN         7.8       7.433  Amazon Prime
# 9170               ['US']     26.0         8.5       7.600  Amazon Prime
# 9171               ['US']      NaN         7.8       7.400  Amazon Prime
#
#       Time Period
# 9167  Before 1964
# 9168  Before 1964
# 9169  Before 1964
# 9170  Before 1964
# 9171  Before 1964

# %%
time_period_counts_amazon = amazon_data_df['Time Period'].value_counts()
time_period_counts_amazon
# Out:
# Time Period
# 2019 to 2023    3477
# 2014 to 2018    2675
# 2004 to 2013    1890
# Before 1964     1200
# 1994 to 2003     663
# 1984 to 1993     434
# 1964 to 1973     269
# 1974 to 1983     265
# Name: count, dtype: int64

# %%
#Binning - HBO
pd.cut(hbo_data_df['Release Year'], Year_bins, labels = bin_labels)
# Out:
# 6137     Before 1964
# 6138     Before 1964
# 6139     Before 1964
# 6140     Before 1964
# 6141     Before 1964
#             ...
# 9162    2019 to 2023
# 9163    2019 to 2023
# 9164    2019 to 2023
# 9165    2019 to 2023
# 9166    2019 to 2023
# Name: Release Year, Length: 3030, dtype: category
# Categories (8, object): ['Before 1964' < '1964 to 1973' < '1974 to 1983' < '1984 to 1993' < '1994 to 2003' < '2004 to 2013' < '2014 to 2018' < '2019 to 2023']

# %%
hbo_data_df['Time Period']=pd.cut(hbo_data_df['Release Year'], Year_bins, labels = bin_labels)
hbo_data_df.head()
# Out:
# C:\Users\zmaso\AppData\Local\Temp\ipykernel_13372\352648140.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hbo_data_df['Time Period']=pd.cut(hbo_data_df['Release Year'], Year_bins, labels = bin_labels)
#                      Title   Type  \
# 6137            Casablanca  MOVIE
# 6138      The Wizard of Oz  MOVIE
# 6139          Citizen Kane  MOVIE
# 6140  Meet Me in St. Louis  MOVIE
# 6141         Tom and Jerry   SHOW
#
#                                             Description  Release Year Rating  \
# 6137  In Casablanca, Morocco in December 1941, a cyn...          1943     PG
# 6138  Young Dorothy finds herself in a magical world...          1939      G
# 6139  Newspaper magnate, Charles Foster Kane is take...          1941     PG
# 6140  In the year before the 1904 St. Louis World's ...          1945    NaN
# 6141  Tom and Jerry is an American animated franchis...          1940    NaN
#
#       Runtime                                             Genres  \
# 6137      102                        ['drama', 'romance', 'war']
# 6138      102                              ['fantasy', 'family']
# 6139      119                                          ['drama']
# 6140      113  ['drama', 'family', 'romance', 'music', 'comedy']
# 6141        8        ['animation', 'comedy', 'family', 'action']
#
#      Production Countries  Seasons  Imdb Score  Tmdb Score Platform  \
# 6137               ['US']      NaN         8.5       8.167      HBO
# 6138               ['US']      NaN         8.1       7.583      HBO
# 6139               ['US']      NaN         8.3       8.022      HBO
# 6140               ['US']      NaN         7.5       7.000      HBO
# 6141               ['US']     16.0         7.7      10.000      HBO
#
#       Time Period
# 6137  Before 1964
# 6138  Before 1964
# 6139  Before 1964
# 6140  Before 1964
# 6141  Before 1964

# %%
time_period_counts_hbo = hbo_data_df['Time Period'].value_counts()
time_period_counts_hbo
# Out:
# Time Period
# 2019 to 2023    783
# 2004 to 2013    627
# 2014 to 2018    493
# 1994 to 2003    338
# Before 1964     296
# 1984 to 1993    239
# 1964 to 1973    135
# 1974 to 1983    119
# Name: count, dtype: int64

# %%
#charting time period counts
combined_period_counts_df = pd.DataFrame({
    'Netflix': time_period_counts_netflix,
    'Amazon': time_period_counts_amazon,
    'HBO': time_period_counts_hbo})#.fillna(0)

#plotting
combined_period_counts_df.plot(kind='bar', figsize=(10, 10))

# Customize the plot
plt.title('Number of Titles on Each Streaming Platform by Time Period')
plt.xlabel('Time Period')
plt.ylabel('Number of Titles')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend(title='Streaming Platform')
plt.grid(True, axis='y')

period_count_path = "output_files/time_period/"
plt.savefig(period_count_path + "time_period_titles.png")

# Show plot
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %% [markdown]
# Targeted Audience and Rating of Titles

# %%
#Rating Mapping
rating_mapping = {
    'TV-MA': 'Mature',
    'R': 'Mature',
    'TV-14': 'Teen',
    'PG-13': 'Teen',
    'PG': 'Family',
    'TV-PG': 'Family',
    'G': 'Family',
    'TV-Y7': "Children",
    'TV-Y': 'Children',
    'TV-G': 'Children',
    'NC-17': 'Mature',
    'TV-Y7-FV': 'Children'}

# %%
#Netflix platform (shows and movies)
netflix_data_df['Grouped Rating'] = netflix_data_df['Rating'].map(rating_mapping)
grouped_netflix_rating_counts = netflix_data_df['Grouped Rating'].value_counts()
grouped_netflix_rating_counts
# Out:
# C:\Users\zmaso\AppData\Local\Temp\ipykernel_13372\2771066505.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   netflix_data_df['Grouped Rating'] = netflix_data_df['Rating'].map(rating_mapping)
# Grouped Rating
# Mature      1534
# Teen         942
# Family       591
# Children     327
# Name: count, dtype: int64

# %%
#Amazon platform (shows and movies)
amazon_data_df['Grouped Rating'] = amazon_data_df['Rating'].map(rating_mapping)
grouped_amazon_rating_counts = amazon_data_df['Grouped Rating'].value_counts()
grouped_amazon_rating_counts
# Out:
# C:\Users\zmaso\AppData\Local\Temp\ipykernel_13372\2282380257.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amazon_data_df['Grouped Rating'] = amazon_data_df['Rating'].map(rating_mapping)
# Grouped Rating
# Mature      1594
# Family       936
# Teen         929
# Children     229
# Name: count, dtype: int64

# %%
#HBO platform (shows and movies)
hbo_data_df['Grouped Rating'] = hbo_data_df['Rating'].map(rating_mapping)
grouped_hbo_rating_counts = hbo_data_df['Grouped Rating'].value_counts()
grouped_hbo_rating_counts
# Out:
# C:\Users\zmaso\AppData\Local\Temp\ipykernel_13372\5364875.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hbo_data_df['Grouped Rating'] = hbo_data_df['Rating'].map(rating_mapping)
# Grouped Rating
# Mature      914
# Teen        513
# Family      413
# Children     71
# Name: count, dtype: int64

# %%
#total titles/ratings pie chart for netflix and save .png

plt.figure(figsize=(8, 8))
plt.pie(grouped_netflix_rating_counts, labels=grouped_netflix_rating_counts.index, autopct='%1.1f%%', 
        startangle=190)

plt.title('Distribution of Ratings on Netflix')

#ensures that pie is drawn as a circle
plt.axis('equal')

#save to output files
netflix_rating_path = "output_files/rating/Netflix/"
plt.savefig(netflix_rating_path + "netflix_rating_titles.png")

plt.show()

# %%
#total titles/ratings pie chart for amazon and save .png

plt.figure(figsize=(8, 8))
plt.pie(grouped_amazon_rating_counts, labels=grouped_amazon_rating_counts.index, autopct='%1.1f%%', startangle=190)

plt.title('Distribution of Ratings on Amazon Prime')

#ensures that pie is drawn as a circle
plt.axis('equal')

#save to output files
amazon_rating_path = "output_files/rating/Amazon Prime/"
plt.savefig(amazon_rating_path + "amazon_rating_titles.png")

plt.show()

# %%
#total titles/ratings pie chart for hbo and save .png

plt.figure(figsize=(8, 8))
plt.pie(grouped_hbo_rating_counts, labels=grouped_hbo_rating_counts.index, autopct='%1.1f%%', startangle=190)

plt.title('Distribution of Ratings on HBO')

#ensures that pie is drawn as a circle
plt.axis('equal')

#save to output files
hbo_rating_path = "output_files/rating/HBO/"
plt.savefig(hbo_rating_path + "hbo_rating_titles.png")

plt.show()
